# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
# Create dataframe with combined dataset
district_data_df = (school_data_complete)
district_data_df.head(10)
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
# 5           5      Bryan Miranda      M   9th  Huang High School
# 6           6      Sheena Carter      F  11th  Huang High School
# 7           7       Nicole Baker      F  12th  Huang High School
# 8           8       Michael Roth      M  10th  Huang High School
# 9           9     Matthew Greene      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# ...

# %%
# Calculate the number of schools in the DataFrame
school_count = len(district_data_df["school_name"].unique())
print(school_count)

# Calculate the total number of students
student_count = len(district_data_df["Student ID"].unique())
print(student_count)

# Calculate the total budget
budget_total = sum(district_data_df ["budget"].unique())
print(budget_total)

# ----AVG -------
# Calculate the average math score
math_average = district_data_df ["math_score"].mean()
print(math_average)

# Calculate the average reading score
read_average = district_data_df ["reading_score"].mean()
print(read_average)

# ----MATH PASSING-------
math_pass = district_data_df.loc[(district_data_df["math_score"])>=70]
math_total = math_pass.count()["Student ID"]
percent_math_pass = ((math_total/student_count)*100)
print(percent_math_pass)

# ----READ PASSING-------
read_pass = district_data_df.loc[(district_data_df["reading_score"])>=70]
read_total = read_pass.count()["Student ID"]
percent_read_pass = ((read_total/student_count)*100)
print(percent_read_pass)

# ----OVERALL PASSING-------
# Calculate the percentage of students who passed math and reading (% Overall Passing)
# locating overall >=70 scores
math_read_pass = district_data_df.loc[(district_data_df["reading_score"]>= 70) & (district_data_df["math_score"]>= 70)]
#print(math_read_pass)

# locating overall >=70 scores and counting by occurrance on Student ID
math_read_total = math_read_pass.count()["Student ID"]

# using that overall count to calculate percentage
overallper = ((math_read_total/student_count)*100)
print(overallper)
# Out:
# 15
# 39170
# 24649428
# 78.98537145774827
# 81.87784018381414
# 74.9808526933878
# 85.80546336482001
# 65.17232575950983

# %%
# Create a dataframe to hold the above results
summary_dicts = [{"Total Schools" : school_count, 
                  "Total Students" : student_count, 
                  "Total School Budget" : budget_total,
                  "Average Math Score" : math_average, 
                  "Average Reading Score" : read_average,
                  "% Passing Math" : percent_math_pass,
                  "% Passing Reading" : percent_read_pass,
                  "% Overall Passing" : overallper}]
district_summary_df = pd.DataFrame(summary_dicts)
district_summary_df
# Out:
#    Total Schools  Total Students  Total School Budget  Average Math Score  \
# 0             15           39170             24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# ---------------SUMMARY BY SCHOOL NAME-----------------

# Set new index by School Name
school_types = school_data.set_index(["school_name"])["type"]
school_budget = school_data.set_index(["school_name"])["budget"]


# school_budget.head(10)
school_types.head(10)
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Name: type, dtype: object

# %%
# Group district data by school -- run print on each variable to check result
grouped_school_df = district_data_df.groupby(["school_name"])
print(grouped_school_df)

# count of students per school -- run print on each variable to check result
students_per_school = grouped_school_df["Student ID"].count().head(10)
print(students_per_school)

# budget per school
budget_per_school = school_budget

# budget per student per school -- run print on each variable to check result
budget_per_student = school_budget/students_per_school
print(budget_per_student)

#Avg math -- run print on each variable to check result
avg_math_per_school = grouped_school_df["math_score"].mean()
print(avg_math_per_school)

#Avg reading -- run print on each variable to check result
avg_read_per_school = grouped_school_df["reading_score"].mean()
print(avg_read_per_school)

# Percent math --
# math_pass = grouped_school_df.loc[(grouped_school_df["math_score"])>=70]
# math_total = math_pass.count()["Student ID"]
# percent_math_pass = ((math_total/student_count)*100)
# print(percent_math_pass)
                                          
# Percent reading --

# Percent overall --
# Out:
# ...
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Name: Student ID, dtype: int64
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School      NaN
# Shelton High School        NaN
# Thomas High School         NaN
# Wilson High School         NaN
# Wright High School         NaN
# dtype: float64
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# ...

# %%
school_dicts =({
    "School Type": school_types,
    "Total Students": students_per_school,
    "Total School Budget": school_budget,
    "Per Student Budget": budget_per_student,
    "Average Math Score": avg_math_per_school,
    "Average Reading Score": avg_read_per_school,
#     "Percent Passing Math": percent_math_pass,
#     "Percent Passing Reading": percent_read_pass,
    "Percent Overall Pass": overallper
})
school_summary_df = pd.DataFrame(school_dicts)
school_summary_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District          4976.0              3124928
# Cabrera High School       Charter          1858.0              1081356
# Figueroa High School     District          2949.0              1884411
# Ford High School         District          2739.0              1763916
# Griffin High School       Charter          1468.0               917500
# Hernandez High School    District          4635.0              3022020
# Holden High School        Charter           427.0               248087
# Huang High School        District          2917.0              1910635
# Johnson High School      District          4761.0              3094650
# Pena High School          Charter           962.0               585858
# Rodriguez High School    District             NaN              2547363
# Shelton High School       Charter             NaN              1056600
# ...

# %%
# Sort and display the top five performing schools by % overall passing.
overall_df = school_df.sort_values("Percent Overall Pass", ascending=False)
overall_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-71d4c45fc0cb> in <module>
#       1 # Sort and display the top five performing schools by % overall passing.
# ----> 2 overall_df = school_df.sort_values("Percent Overall Pass", ascending=False)
#       3 overall_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
# ...

# %%
# Sort and display the bottom five performing schools by % overall passing.
overall_df = school_df.sort_values("Percent Overall Pass", ascending=True)
overall_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-b5e869844934> in <module>
#       1 # Sort and display the bottom five performing schools by % overall passing.
# ----> 2 overall_df = school_df.sort_values("Percent Overall Pass", ascending=True)
#       3 overall_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
# ...

# %%
# -----------MATH SCORES BY GRADE-----------
# Create a table that lists the average Math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

math_average = district_data_df ["math_score"].mean()
print(math_average)

# Create a pandas series for each grade. Hint: use a conditional statement.
student_grade = school_data_complete.set_index(["school_name"])["9th"],["10th"],["11th"],["12th"]
ninth = district_data_df.loc[district_data_df["grade"] == "9th"]
tenth = district_data_df.loc[district_data_df["grade"] == "10th"]
elev = district_data_df.loc[district_data_df["grade"] == "11th"]
twel = district_data_df.loc[district_data_df["grade"] == "12th"]


# Group each series by school
grouped_school_df = district_data_df.groupby(["school_name"])
print(grouped_school_df)

# Combine the series into a dataframe
math_by_grade =({
    "9th": ninth,
    "10th": tenth,
    "11th": elev,
    "12th": twel,
})
math_scores_df = pd.DataFrame(math_by_grade)
math_scores_df

# Optional: give the displayed data cleaner formatting
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '9th'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-9299e3d9ba9c> in <module>
#       3
# ...

# %%
#------------ Reading Score by Grade------------
# Perform the same operations as above for reading scores

# %%
#----------- Scores by School Spending---------
# Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
# Average Math Score
# Average Reading Score
# % Passing Math
# % Passing Reading
# Overall Passing Rate (Average of the above two)

# %%
# ----------Scores by School Size--------------
# Perform the same operations as above, based on school size.

# %%
# --------------Scores by School Type------------
# Perform the same operations as above, based on school type
